# %% [markdown]
# #Funciones
#
#
# *   Divide y venceras
# *   Serie de instrucciones que logran un objetivo
# *   Funcion ligada a un proceso transferencia/retorno
# *   Permite reutilizar codigo
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Declaracion
#
#
#
# ```
# def nombre_funcion(parametros):
#   instruccion_1
#   instruccion_2
#
# ```
#
# Consideraciones
#
#
# * Puede empezar con una letra o con un subguión ( _ )
# * No debe de contener espacios en blanco
# * No se puede utilizar nombres de funciones propias de python
# * Debe ser intuitivo

# %% [markdown]
# ##Ejemplo
#
#
#
# ```
# def funcion_suma(a,b):
#   return a+b
#
# n1=4
# n2=5
# suma=funcion_suma(n1,n2)
# print(suma)
# ```
# 9

# %%
def desplegar_menu(titulo):
  titulo=titulo.upper()
  print(titulo)
  print("1.PRIMERA OPCION\n2.Segunda ocpion")

# %%
def generarLista(lista2,numero):
  lista=lista2.copy()
  lista.remove(numero)
  return lista

# %%
lista=[1,2,3,4]
lista2=generarLista(lista,3)
print(lista2)
print(lista)
# Out:
# [1, 2, 4]
# [1, 2, 3, 4]

# %%
def imprimir():
  print("hola")
imprimir()
# Out:
# hola

# %% [markdown]
# ##Ejercicio 1
#
#
# ```
# Dice la historia que la criptografía fue utilizada por los gobiernos para
# comunicaciones secretas durante las campañas militares.
#
# En el siglo I A.C., Julio César usó un algoritmo que consistía en desplazar
# tres espacios hacia la derecha las letras del texto siguiendo el orden
# alfabético.
#
# Realice una función cifradocesar (mensaje, llave) que usa una variante del
# método descrito para cifrar el mensaje, desplazando cada letra del mensaje en
# el alfabeto las posiciones que indique la “llave”. Con el resultado, el mensaje
# original no es reconocido a menos que se use el valor negativo de la “llave”.
#
# Considerar que siguiente posición de la letra “Z” será la “A”, y la anterior a
# la letra “A” será la “Z”.
#
# Ejemplo:
# >> mensaje=’HOLA’ , llave=+3;
# >> cifradocesar(mensaje,llave)
#  ans=KROD
# >> mensaje=’KROD’ , llave =-3;
# >> cifradocesar(mensaje,llave)
#  ans=HOLA
#
# ```

# %%
def cifradoCesar(mensaje,llave):
  abecedario="ABCDEFGHIJKLMNOPQRSTUVWXYZ"
  mensajeCifrado=""
  mensaje=mensaje.upper()
  for letra in mensaje:
    indice_original=abecedario.find(letra)
    indice_desplazado=indice_original+llave
    if (indice_desplazado+1>len(abecedario)):
      indice_desplazado=indice_desplazado-len(abecedario)
    mensajeCifrado+=abecedario[indice_desplazado]
  return mensajeCifrado

# %%
mensajeCifrado=cifradoCesar("holz",3)
print(mensajeCifrado)
print(cifradoCesar(mensajeCifrado,-3))
# Out:
# KROC
# HOLZ

# %% [markdown]
# ##Ejercicio 2
#
#
# ```
# Una empresa robótica quiere etiquetar a sus robots con un nombre de n
# caracteres, alternando entre letras y números escogidos de forma aleatoria.
# Realice una función nrobot(n) para obtener lo requerido.
#
# Ejemplo:
# >> nrobot(4)
#  ans = R2D2
#
# >> nrobot(5)
#  ans = C3P0K
# ```

# %%
import random as rd

# %%
def nrobot(numero_caracteres):
  abecedario="ABCDEFGHIJKLMNOPQRSTUVWXYZ"
  nombre=""
  for i in range(numero_caracteres):
    if i%2==0:
      letra=rd.choice(abecedario)
      nombre+=letra
    else:
      n_aleatorio=str(rd.randrange(1,9))
      nombre+=n_aleatorio

  return nombre

# %%
print(nrobot(5))
print(nrobot(8))
# Out:
# S4Y7H
# Y4N5H4Z4

# %% [markdown]
# ##Ejercicio 3
#
#
#
# ```
# A usted se le solicita crear la funcion calcularHoras(linea). Recibe un String
# con el sgt formato:
# Fecha-dia-feriado-ID-nombre-sucursal-ciudad-horas_trabajadas
#
# y determina las horas trabajadas para cada categoría. El resultado es una lista
# con el identificador del empleado, ciudad y horas trabajadas regulares, extras
# fines de semana y feriado.
#
# VH,10,Valor Hora en ésta compañía
# HR,1,Factor Horas Regulares
# HER,1.21,Factor Horas Extras en dias Regulares (lunes-viernes)
# HFDS,1.37,Factor Horas en Fin De Semana (Sabado o domingo)
# HF,1.39,Factor Horas en Feriado
# Fecha,dia,feriado,ID,nombre,sucursal,ciudad,horas-trabajadas
#
# Ejemplo:
# >>> linea = "09-Agosto-2018,4,No,FG848801,Fabricio Granados, River Mall, Cuenca,9"
# >>> calcularHoras(linea)
# ['FG848801','Cuenca',8,1,0]
# ```

# %%
def calcularHoras(linea):
  lista=linea.split(",")
  horas=float(lista[-1])
  exdente=0
  if horas>8:
    exedente=horas-8
  lista_retorno=[lista[3],lista[-2],8,exedente,0]
  return  lista_retorno

# %%
calcularHoras("09-Agosto-2018,4,No,FG848801,Fabricio Granados, River Mall, Cuenca,9")
# Out:
# ['FG848801', ' Cuenca', 8, 1.0, 0]

# %% [markdown]
# ##Ejercicio 4
#
#
#
# ```
# A usted se le solicita implementar en Python:
# 1. La función dibujarEspejo que recibe un número n y dibuja el siguiente
# patrón: [20%]
# Nota: Asuma que n es siempre un número par.
#
# ```
# ![image.png](data:image/png;base64,...)

# %%
def dibujarEspejo(n):
  print("#"+"="*(n*2)+"#")
  for i in range(n):
    cantidad_puntos=0
    if i<n//2:
      cantidad_puntos=i
    else:
      cantidad_puntos=(n-1)-i

    puntitos="<>"+ "...."*cantidad_puntos + "<>"
    puntitos="|"+puntitos.center(4*(n//2))+"|"
    print(puntitos)
  print("#"+"="*(n*2)+"#")

# %%
dibujarEspejo(12)
# Out:
# #========================#
# |          <><>          |
# |        <>....<>        |
# |      <>........<>      |
# |    <>............<>    |
# |  <>................<>  |
# |<>....................<>|
# |<>....................<>|
# |  <>................<>  |
# |    <>............<>    |
# |      <>........<>      |
# |        <>....<>        |
# |          <><>          |
# #========================#

# %% [markdown]
# ##Ejercicio 5
#
#
#
# ```
# Se le solicita crear un menu en donde el usuario tenga dos opciones, una para
# verificar si la cecula es valida y otro para consultar los pagos a realizar, en
# el caso de querer terminar el programa el usuario debera escribir salir, en
# caso de que quiera regresar el menu principal debera escribir regresar.
#
# a)Para verificar la cedula deber crear la funcion verificarCedula(cedula),
# se sabe que para que una cedula sea valida debe cumplir los siguientes requisitos:
#
# * La cédula ecuatoriana está formada por los dos primeros dígitos que
#   corresponden a la provincia donde fue expedida, por lo cual, los dos primeros
#   dígitos no serán mayores a 24 ni menores a 0.
# * El tercer dígito es un número menor a 6 (0,1,2,3,4,5).
# * Los siguientes hasta el noveno dígito son un número consecutivo.
# * El décimo es el dígito verificador.
# ejemplo:
# ```
# ![texto alternativo](https://miro.medium.com/max/576/1*hmxY-cZSOw5juGZoGbNeCQ.png)
#
#
#
# ```
# b) Para la segunda consulta se tienen que crear dos funciones:
#     *La primera para generar listas paralelas en donde la primera lista
#      contendra la cedula de una persona, la segunda lista el total de las
#      compras que ha realizado y la tercera los nombres, para ello creara la
#      funcion generarListas(lista) la cual recibe una lista  de la siguiente
#      forma:
#      ["cedula-nombre-producto-precio-cantidad",...]
# ejemplo:
# >>lista=["0951690148-Carlos Loja-queso-1-8","0951697167-Camila Tapia-queso-2.5-8","0951690148-Carlos Loja-sacoArroz-50-2",..]
# >>generarListas(lista)
# [["0951690167",...],[108.0,...],["Carlos Loja",...]]
#
#     *La segunda funcion imprimirGastos(cedula) el cual utiliza la funcion
#      realizada anteriormente para obtener las listas paralelas y asi poder
#      buscar la cedula ingresada en las mismas y obtener los gastos que ha
#      realizado.
#
# ejemplo de salida del programa:
#
# Opciones
# 1.Verficar cedula
# 2.Obtener gastos
# >>ingrese la opcion: 1
# >>ingrese cedula: 0951690147
# Cedula no valida
# >>Desea ingresar una nueva cedula?(s/n): s
# >>ingrese cedula: 0951690148
# Cedula valida
# >>Desea ingresar una nueva cedula?(s/n): n
#
# Opciones
# 1.Verficar cedula
# 2.Obtener gastos
# >>ingrese la opcion: 2
# >>ingrese cedula: 0951690148
# Carlos loja a gastado $108.0
# >>Desea ingresar una nueva cedula?(s/n): n
#
# Opciones
# 1.Verficar cedula
# 2.Obtener gastos
# >>ingrese la opcion: salir
#
#
#
# ```

# %%
opcion=""
while opcion!="salir":
  print("1.Verificar cedula\n2.Obtener Gastos")
  opcion=input("Ingrese opcion: ")

  if opcion=="1":
    cedula=input("Ingrese Cedula: ")
    #verificarCedula(cedula)

  elif opcion=="2":
    pritn("Otro metodo")
  opcion=input("Quieres continuar: ")
# Out:
# 1.Verificar cedula
# 2.Obtener Gastos
# Ingrese opcion: salir
# Quieres continuar: salir

# %%
def verificarCedula(cedula):
  primerosDigitos=int(cedula[0:2])
  tercero=int(cedula[2])
  decimo=int(cedula[-1])
  if 0<=primerosDigitos<24 and (tercero in range(6)):
    contador=0
    suma=0
    for i in cedula:
      if contador%2==0:
        numero=int(cedula)*2
      else:
        numero=int(cedula)*1
      if numero >=10:
        numero=numero-9

      suma+=numero
      contador+=1
    resta=30-suma
    return str(resta)==decimo

# %% [markdown]
# * La cédula ecuatoriana está formada por los dos primeros dígitos que
#   corresponden a la provincia donde fue expedida, por lo cual, los dos primeros
#   dígitos no serán mayores a 24 ni menores a 0.
# * El tercer dígito es un número menor a 6 (0,1,2,3,4,5).
# * Los siguientes hasta el noveno dígito son un número consecutivo.
# * El décimo es el dígito verificador.
# ![texto alternativo](https://miro.medium.com/max/576/1*hmxY-cZSOw5juGZoGbNeCQ.png)
